# %% [markdown]
# # AI Image Studio
#
# Generate beautiful AI art with Stable Diffusion!

# %%
# Install dependencies
# !pip install gradio diffusers transformers accelerate -q

# %%
import gradio as gr

def generate_image(prompt, style):
    return f'Generating: {prompt} in {style} style'

styles = ['Cinematic', 'Anime', 'Fantasy', 'Cyberpunk', 'Realistic']

with gr.Blocks() as demo:
    gr.Markdown('# AI Image Studio')
    prompt = gr.Textbox(label='Enter prompt')
    style = gr.Dropdown(styles, label='Style')
    btn = gr.Button('Generate')
    output = gr.Textbox(label='Output')
    btn.click(generate_image, [prompt, style], output)

demo.launch(share=True)
